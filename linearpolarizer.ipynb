# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

angle = np.array(np.linspace(0, 360, 37)).tolist()

ex_angle = np.linspace(45, 315, 4).tolist()

tot_angle = angle + ex_angle + [175]

pos = [119, 131, 132, 129, 95.2, 60.1, 28.2, 9.56, 2.41, 0.945, 4.50, 40.5, 171, 491, 1000, 1670, 2190, 2580, 2580, 2230, 1640, 1050, 562, 262, 89.6, 22.7, 3.76, .943, 1.65, 3.93, 9.69, 19.4, 33.1, 51.8, 70.7, 96.1, 120, 76.1, 734, 442, 26.1, 2630]

neg = [255, 449, 806, 1180, 1390, 1330, 1010, 634, 288, 170, 304, 648, 1020, 1290, 1310, 1060, 681, 299, 148, 297, 679, 1110, 1440, 1460, 1200, 766, 402, 237, 364, 705, 1140, 1380, 1350, 1050, 660, 340, 257, 1380, 1320, 1460, 1390, 202]

plt.figure()

plt.scatter(tot_angle, pos, color="orange", linestyle="-", marker="o")
plt.scatter(tot_angle, neg, color="blue", linestyle="-", marker="o")

plt.show()
