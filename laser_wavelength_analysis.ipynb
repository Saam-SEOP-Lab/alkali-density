# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

## current reads 0.539
w_539 = np.array([793.787, 793.811, 793.802, 793.811, 793.813, 793.827, 793.849, 793.880, 793.914, 793.987, 794.059, 794.146, 794.231, 794.331, 794.434, 794.546, 794.672, 794.699, 794.732, 794.762, 794.788, 794.817, 794.863, 794.911, 794.966, 795.057])
w_539_error = np.array([0.004, 0.034, 0.003, 0.004, 0.003, 0.004, 0.003, 0.008, 0.005, 0.007, 0.003, 0.003, 0.005, 0.005, 0.007, 0.003, 0.004, 0.008, 0.005, 0.003, 0.003, 0.005, 0.006, 0.005, 0.007, 0.003])
temp_539 = np.array([1.998, 1.980, 1.970, 1.960, 1.950, 1.930, 1.900, 1.850, 1.800, 1.700, 1.600, 1.500, 1.400, 1.299, 1.200, 1.100, 1.000, 0.980, 0.960, 0.940, 0.920, 0.900, 0.870, 0.840, 0.810, 0.780])

temp_700 = np.array([1.307, 1.2, 1.1, 1, 0.98, 0.959, 0.939, 0.919, 0.9, 0.87, 0.84, 0.810, 0.780, 0.760, 0.740, 0.730, 0.720, 0.700, 0.690])
w_700 = np.array([794.3398571, 794.4578571, 794.5712857, 794.6974286, 794.721, 794.7508571, 794.787, 794.5614286, 794.8448571, 794.8888571, 794.9407143, 794.9841429, 795.0468571, 795.0808571, 795.12, 795.1454286, 795.1582857, 795.197, 795.2182857])
w_700_error = np.array([0.007, 0.005, 0.007, 0.012, 0.011, 0.008, 0.009, 0.665, 0.008, 0.004, 0.009, 0.006, 0.008, 0.007, 0.006, 0.014, 0.011, 0.004, 0.007])

temp_600 = np.array([1.998, 1.960, 1.930, 1.101, 1.000, 0.980, 0.960, 0.940, 0.920, 0.900, 0.870, 0.840, 0.810, 0.790, 0.780, 0.770, 0.760, 0.750, 0.740, 0.730])
w_600 = np.array([793.7952857, 793.8265714, 793.852, 794.57, 794.6962857, 794.7222857, 794.7548571, 794.7862857, 794.8125714, 794.8462857, 794.8932857, 794.9427143, 794.9902857, 795.0262857, 795.0448571, 795.064, 795.0751429, 795.0987143, 795.1187143, 795.0972857])
w_600_error = np.array([0.008, 0.003, 0.002, 0.014, 0.012, 0.013, 0.007, 0.007, 0.009, 0.010, 0.004, 0.006, 0.006, 0.010, 0.008, 0.009, 0.006, 0.005, 0.008, 0.008])

#figure setup
fig = plt.figure()
ax = fig.add_subplot()
fig.subplots_adjust(top=0.89)

#plot the data sets
ax.errorbar(x=temp_539, y=w_539, yerr=w_539_error, color='blue', marker='o', linestyle='none', label = 'current=135 mA')
#ax.errorbar(x=temp_700, y=w_700, yerr=w_700_error, color='orange', marker='o', linestyle='none', label = 'current=175 mA')
#ax.errorbar(x=temp_600, y=w_600, yerr=w_600_error, color='green', marker='o', linestyle='none', label = 'current=150 mA')

#run at 200mA for next trial
#could maybe go up as high as 250mA
#also test the D2 this way as well

#set up labels, titles, grid
fig.suptitle("resistance vs temp")
ax.set_title("")
ax.legend()
ax.set_xlabel("resistance")
ax.set_ylabel("wavelength (nm)")
ax.grid(visible=True, which='both', axis='both')


#display the plot
plt.show()

# %%
import pyvisa
import re

import pyvisa
rm = pyvisa.ResourceManager()
a = list(rm.list_resources())


print(a.index('ASRL1::'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 6
#       4 rm = pyvisa.ResourceManager()
#       5 a = list(rm.list_resources())
# ----> 6 print(a.index('ASRL1::'))
#
# ValueError: 'ASRL1::' is not in list
